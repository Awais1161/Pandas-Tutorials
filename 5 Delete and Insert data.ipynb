# %% [markdown]
# # Delete and Insert

# %%
import pandas as pd
var= pd.DataFrame({'A':[1,2,3,4,5], 'B':[9,8,7,6,5]})
var
# Out:
#    A  B
# 0  1  9
# 1  2  8
# 2  3  7
# 3  4  6
# 4  5  5

# %%
var.insert(1,'python', var['A'])   # syntex: var.insert(3 parameters)(kis jga, column name, jo insert krna)
var
# Out:
#    A  python  B
# 0  1       1  9
# 1  2       2  8
# 2  3       3  7
# 3  4       4  6
# 4  5       5  5

# %%
var.insert(3,'python_1', [15,16,17,18,18])   
var
# Out:
#    A  python  B  python_1
# 0  1       1  9        15
# 1  2       2  8        16
# 2  3       3  7        17
# 3  4       4  6        18
# 4  5       5  5        18

# %%
import pandas as pd
var= pd.DataFrame({'A':[1,2,3,4,5], 'B':[9,8,7,6,5]})
var
# Out:
#    A  B
# 0  1  9
# 1  2  8
# 2  3  7
# 3  4  6
# 4  5  5

# %%
var['python']=var['A'][:3]
var
# Out:
#    A  B  python
# 0  1  9     1.0
# 1  2  8     2.0
# 2  3  7     3.0
# 3  4  6     NaN
# 4  5  5     NaN

# %% [markdown]
# # Delete

# %%
import pandas as pd
var= pd.DataFrame({'A':[1,2,3,4,5], 'B':[9,8,7,6,5], 'C': [11,12,12,13,14]})
var
# Out:
#    A  B   C
# 0  1  9  11
# 1  2  8  12
# 2  3  7  12
# 3  4  6  13
# 4  5  5  14

# %%
var1=var.pop('B')
var1
# Out:
# 0    9
# 1    8
# 2    7
# 3    6
# 4    5
# Name: B, dtype: int64

# %%
var
# Out:
#    A   C
# 0  1  11
# 1  2  12
# 2  3  12
# 3  4  13
# 4  5  14

# %%
del var['A']
var
# Out:
#     C
# 0  11
# 1  12
# 2  12
# 3  13
# 4  14

# %%
import pandas as pd
var= pd.DataFrame({'A':[1,2,3,4,5], 'B':[9,8,7,6,5], 'C': [11,12,12,13,14]})
var
# Out:
#    A  B   C
# 0  1  9  11
# 1  2  8  12
# 2  3  7  12
# 3  4  6  13
# 4  5  5  14

# %%
del var['B']
var
# Out:
#    A   C
# 0  1  11
# 1  2  12
# 2  3  12
# 3  4  13
# 4  5  14
